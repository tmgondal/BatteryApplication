# %%
import pandas as pd, textwrap, pprint, re
sample_path = r"C:\Dataset\Segmented\Characterization\WWH_18650_cell1a_charac0000.csv"   # ➟ change to one that exists
print("\nColumns & dtypes:\n")
print(pd.read_csv(sample_path, nrows=0).columns.tolist())

# Optional: peek at first three rows
print("\nHead(3):\n")
pprint.pp(pd.read_csv(sample_path, nrows=3).to_dict(orient="records"))
# Out:
# Columns & dtypes:
#
# ['Test_ID', 'Data_Point', 'Test_Time', 'Step_Time', 'DateTime', 'Step_Index', 'Cycle_Index', 'Is_FC_Data', 'Current', 'Voltage', 'Charge_Capacity', 'Discharge_Capacity', 'Charge_Energy', 'Discharge_Energy', 'dV/dt', 'Internal_Resistance', 'AC_Impedance', 'ACI_Phase_Angle']
#
# Head(3):
#
# [{'Test_ID': 1,
#   'Data_Point': 1,
#   'Test_Time': 1.078445,
#   'Step_Time': 1.006278,
#   'DateTime': 44128.392199,
#   'Step_Index': 11,
#   'Cycle_Index': 1,
#   'Is_FC_Data': 0,
#   'Current': -0.367568,
#   'Voltage': 3.506064,
#   'Charge_Capacity': 0.0,
#   'Discharge_Capacity': 0.000102,
#   'Charge_Energy': 0.0,
#   'Discharge_Energy': 0.00036,
#   'dV/dt': -0.000215,
#   'Internal_Resistance': 0.0,
#   'AC_Impedance': 0.0,
#   'ACI_Phase_Angle': 0.0},
#  {'Test_ID': 1,
#   'Data_Point': 2,
#   'Test_Time': 2.093404,
#   'Step_Time': 2.021236,
#   'DateTime': 44128.39221,
#   'Step_Index': 11,
#   'Cycle_Index': 1,
#   'Is_FC_Data': 0,
#   'Current': -0.367647,
# ...

# %%
import pandas as pd, textwrap, pprint, re
sample_path = r"C:\Dataset\Segmented\Final_EIS\WWH_18650_cell1a_final_soc000pct.csv"   # ➟ change to one that exists
print("\nColumns & dtypes:\n")
print(pd.read_csv(sample_path, nrows=0).columns.tolist())

# Optional: peek at first three rows
print("\nHead(3):\n")
pprint.pp(pd.read_csv(sample_path, nrows=3).to_dict(orient="records"))
# Out:
# Columns & dtypes:
#
# ['Number', 'Frequency/Hz', 'impedance', 'R/Ohm', 'impedance.1', 'I/Ohm', 'Significance', 'Time/s']
#
# Head(3):
#
# [{'Number': 1,
#   'Frequency/Hz': 1008.5,
#   'impedance': 0.026032,
#   'R/Ohm': -0.0025178,
#   'impedance.1': 1.0,
#   'I/Ohm': 0.0,
#   'Significance': nan,
#   'Time/s': nan},
#  {'Number': 2,
#   'Frequency/Hz': 1269.1,
#   'impedance': 0.025598,
#   'R/Ohm': -0.0022768,
#   'impedance.1': 1.0,
#   'I/Ohm': 2.8,
#   'Significance': nan,
#   'Time/s': nan},
#  {'Number': 3,
#   'Frequency/Hz': 1597.0,
#   'impedance': 0.025174,
#   'R/Ohm': -0.0020158,
#   'impedance.1': 1.0,
#   'I/Ohm': 4.4,
#   'Significance': nan,
#   'Time/s': nan}]

# %%
import pandas as pd, textwrap, pprint, re
sample_path = r"C:\Dataset\Segmented\Initial_EIS\WWH_18650_cell1a_initial_soc000pct.csv"   # ➟ change to one that exists
print("\nColumns & dtypes:\n")
print(pd.read_csv(sample_path, nrows=0).columns.tolist())

# Optional: peek at first three rows
print("\nHead(3):\n")
pprint.pp(pd.read_csv(sample_path, nrows=3).to_dict(orient="records"))
# Out:
# Columns & dtypes:
#
# ['Number', 'Frequency/Hz', 'impedance', 'R/Ohm', 'impedance.1', 'I/Ohm', 'Significance', 'Time/s']
#
# Head(3):
#
# [{'Number': 1,
#   'Frequency/Hz': 1008.5,
#   'impedance': 0.019036,
#   'R/Ohm': -0.0014614,
#   'impedance.1': 0.999,
#   'I/Ohm': 0.0,
#   'Significance': nan,
#   'Time/s': nan},
#  {'Number': 2,
#   'Frequency/Hz': 1269.1,
#   'impedance': 0.018719,
#   'R/Ohm': -0.001182,
#   'impedance.1': 1.0,
#   'I/Ohm': 2.4,
#   'Significance': nan,
#   'Time/s': nan},
#  {'Number': 3,
#   'Frequency/Hz': 1597.0,
#   'impedance': 0.018437,
#   'R/Ohm': -0.00081746,
#   'impedance.1': 1.0,
#   'I/Ohm': 4.0,
#   'Significance': nan,
#   'Time/s': nan}]

# %%
import pandas as pd, textwrap, pprint, re
sample_path = r"C:\Dataset\Segmented\Summaries\WWH_18650_cell1a_finalcharac.csv"   # ➟ change to one that exists
print("\nColumns & dtypes:\n")
print(pd.read_csv(sample_path, nrows=0).columns.tolist())

# Optional: peek at first three rows
print("\nHead(3):\n")
pprint.pp(pd.read_csv(sample_path, nrows=3).to_dict(orient="records"))
# Out:
# Columns & dtypes:
#
# ['Test_ID', 'Data_Point', 'Test_Time', 'Step_Time', 'DateTime', 'Step_Index', 'Cycle_Index', 'Is_FC_Data', 'Current', 'Voltage', 'Charge_Capacity', 'Discharge_Capacity', 'Charge_Energy', 'Discharge_Energy', 'dV/dt', 'Internal_Resistance', 'AC_Impedance', 'ACI_Phase_Angle']
#
# Head(3):
#
# [{'Test_ID': 1,
#   'Data_Point': 1,
#   'Test_Time': 1.087401,
#   'Step_Time': 1.007953,
#   'DateTime': 44835.659907,
#   'Step_Index': 11,
#   'Cycle_Index': 1,
#   'Is_FC_Data': 0,
#   'Current': -0.367414,
#   'Voltage': 3.555746,
#   'Charge_Capacity': 0.0,
#   'Discharge_Capacity': 0.000102,
#   'Charge_Energy': 0.0,
#   'Discharge_Energy': 0.000366,
#   'dV/dt': -0.000571,
#   'Internal_Resistance': 0.0,
#   'AC_Impedance': 0.0,
#   'ACI_Phase_Angle': 0.0},
#  {'Test_ID': 1,
#   'Data_Point': 2,
#   'Test_Time': 2.09553,
#   'Step_Time': 2.016082,
#   'DateTime': 44835.659918,
#   'Step_Index': 11,
#   'Cycle_Index': 1,
#   'Is_FC_Data': 0,
#   'Current': -0.36749,
# ...
